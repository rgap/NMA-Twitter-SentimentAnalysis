# %% [markdown]
# # Download the csv data to the raw data folder

# %%
import requests, zipfile, io
url = 'https://github.com/rgap/NMA-Twitter-SentimentAnalysis/raw/main/data/raw/trainingandtestdata.zip'
raw_data_directory = 'data/raw/'
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall(path=raw_data_directory)

# %% [markdown]
# # 1. Read the CSV

# %%
import pandas as pd

raw_data_directory = 'data/raw/'

# We load the dataset
header_list = ["polarity", "id", "date", "query", "user", "text"]
df = pd.read_csv(raw_data_directory + 'training.1600000.processed.noemoticon.csv',
                 encoding = "ISO-8859-1", names=header_list)

# Let's have a look at it
df.head(2)
# Out:
#    polarity          id                          date     query  \
# 0         0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1         0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...

# %% [markdown]
# # 2.  Splitting features

# %%
## Features
features = ['id', 'date', 'query', 'user', 'text']
## Target
target = 'polarity'

## Transform the polarity column into just 0s and 1s because it has only 2 unique values
df[target] = df[target].map({0: 0, 4: 1})
## The column type should be int
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-11-33a5fc231375> in <cell line: 9>()
#       7 df[target] = df[target].map({0: 0, 4: 1})
#       8 ## The column type should be int
# ----> 9 df[target] = df[target].astype(int)
#      10 df.head(10)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6322         else:
#    6323             # else, only a single dtype is given
# -> 6324             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325             return self._constructor(new_data).__finalize__(self, method="astype")
#    6326
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     449             copy = False
#     450
# --> 451         return self.apply(
#     452             "astype",
# ...

# %%
# Check if there are non-finite values (NA or inf) in column polarity
df.isna().sum()
# Check if there are
# Out:
# polarity    800000
# id               0
# date             0
# query            0
# user             0
# text             0
# dtype: int64
